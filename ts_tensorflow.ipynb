# %%
import pandas as pd
import os
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
#from tensorflow.models.rnn import *
from tensorflow.contrib import rnn
import os

# %%
data = 'data/weather_30000.csv'
df = pd.read_csv(data)
df.head()
# Out:
#   UTC_Date  TempM  DewPointM  Humidity  WindSpeedM  VisibilityM  PressureA
# 0  51:00.0   22.8       12.8        53        11.1         16.1      30.08
# 1  51:00.0   21.7       13.3        59         7.4         16.1      30.07
# 2  51:00.0   20.0       13.3        65        16.7         16.1      30.06
# 3  51:00.0   19.4       13.3        68         9.3         16.1      30.06
# 4  51:00.0   18.9       13.3        70         5.6         16.1      30.04

# %%
#for col in list(df.columns)
cols = list(df.columns)
print cols
#print len(df)
#print len(df.loc[~(df['VisibilityM']==-9999)])
# Out:
# ['UTC_Date', 'TempM', 'DewPointM', 'Humidity', 'WindSpeedM', 'VisibilityM', 'PressureA']

# %%
def preprocess(df):   
    cols = ['TempM', 'DewPointM', 'Humidity', 'WindSpeedM', 'VisibilityM', 'PressureA']
    df = df[cols]
    for col in cols:
        df = df.loc[~(df[col]==-9999)]
        df = df[~(df.isnull())]
    df = df.reset_index(drop = True)
    return df

# %%
df1 = preprocess(df)
df1.describe()
# Out:
#               TempM     DewPointM      Humidity    WindSpeedM   VisibilityM  \
# count  27534.000000  27534.000000  27534.000000  27534.000000  27534.000000
# mean      12.885694      5.152045     62.560471      8.710776     13.188265
# std       10.170781     11.057698     19.880571      6.082485      4.789264
# min      -18.300000    -28.300000      9.000000      0.000000      0.400000
# 25%        4.400000     -3.300000     46.000000      5.600000     11.300000
# 50%       13.900000      6.700000     62.000000      7.400000     16.100000
# 75%       21.700000     14.400000     81.000000     13.000000     16.100000
# max       35.600000     25.600000    100.000000    137.000000     16.100000
#
#          PressureA
# count  27534.00000
# mean      30.02106
# std        0.22912
# min       29.02000
# 25%       29.88000
# 50%       30.02000
# 75%       30.17000
# max       30.82000

# %%
scaler = MinMaxScaler((0,1))
def get_batch(df,batch_size = 128, T = 16, input_dim = 6, step = 0, train = True):
    
    t = step*batch_size
    X_batch = np.empty(shape = [batch_size,T,input_dim])
    y_batch = np.empty(shape = [batch_size,T])
    labels = np.empty(shape = [batch_size])
    
    for i in range(batch_size):
        X_batch[i,:] = scaler.fit_transform(df.iloc[t:t+T].values)
        y_batch[i,:] = df["TempM"].iloc[t:t+T].values
        labels[i] = df["TempM"].iloc[t+T]
        t += 1     
    
    ## shuffle in train, not in test
    if train:
        index = range(batch_size)
        np.random.shuffle(index)
        X_batch = X_batch[index]
        y_batch = y_batch[index]
        labels = labels[index]

    return X_batch,y_batch,labels

# %%
class ts_prediction(object):
    
    def __init__(self, input_dim, time_step, n_hidden, d_hidden, batch_size):

        self.batch_size = batch_size
        self.n_hidden = n_hidden
        self.d_hidden = d_hidden
        self.o_hidden = 32
        
        self.input_dim = input_dim
        self.time_step = time_step
        
        self.seq_len = tf.placeholder(tf.int32,[None])
        self.input_x = tf.placeholder(dtype = tf.float32, shape = [None, None, input_dim])
        self.input_y = tf.placeholder(dtype = tf.float32,shape = [None,self.time_step])
        self.label = tf.placeholder(dtype = tf.float32)
        
        self.encode_cell = tf.contrib.rnn.LSTMCell(self.n_hidden, forget_bias=1.0, state_is_tuple=True)
        self.decode_cell = tf.contrib.rnn.LSTMCell(self.d_hidden, forget_bias=1.0, state_is_tuple=True)
        self.output_cell = tf.contrib.rnn.LSTMCell(self.o_hidden, forget_bias=1.0, state_is_tuple=True)
        
        self.loss = tf.constant(0.0)
            ## ===========  build the model =========== ##
            
            ## ==== encoder ===== ## 
        out = self.en_RNN(self.input_x) # out[0]: (b*T*2d)
        self.out = out
        out = tf.transpose(out,[0,2,1]) # (b,2d,T)
        with tf.name_scope('encoder') as scope:
            stddev = 1.0/(self.n_hidden*self.time_step)
            Ue = tf.Variable(dtype=tf.float32,
                             initial_value = tf.truncated_normal(shape = [self.time_step,self.time_step], 
                                                                 mean = 0.0, stddev = stddev),name = 'Ue')
        var = tf.tile(tf.expand_dims(Ue,0),[self.batch_size,1,1]) #(b,T,T)
        
        batch_mul = tf.matmul(var,self.input_x) # (b*T*T)*(b*T*d) = (b,T,d)
        self.out = batch_mul
        e_list = []

        for k in range(self.input_dim):
            series_k = tf.reshape(batch_mul[:,:,k],[self.batch_size,self.time_step,1]) #(b,T,1)
            e_k = self.attention(out,series_k, scope = 'encoder')
            e_list.append(e_k)
        e_list = tf.concat(e_list,axis = 1)
        soft_attention = tf.nn.softmax(e_list,dim = 1)
        input_attention = tf.multiply(self.input_x,tf.transpose(soft_attention,[0,2,1])) #(b,T,d)
        
        with tf.variable_scope('fw_lstm') as scope:
            tf.get_variable_scope().reuse_variables()
            h,_ = tf.nn.dynamic_rnn(self.encode_cell, input_attention, self.seq_len, dtype = tf.float32)
        # h: (b,T,d)
        
            # ===== decoder ===== ## 
        d, dec_out = self.de_RNN(h) ## d: (b,T,q); dec_out:(b,T,2q)
        self.out = d
        dec_out = tf.transpose(dec_out,[0,2,1])
        with tf.name_scope('decoder') as scope:
            stddev = 1.0/(self.d_hidden*self.time_step)
            Ud = tf.Variable(dtype=tf.float32,
                             initial_value = tf.truncated_normal(shape = [self.n_hidden,self.n_hidden], 
                                                                 mean = 0.0, stddev = stddev),name = 'Ud')
        de_var = tf.tile(tf.expand_dims(Ud,0),[self.batch_size,1,1]) # (b,d,d)
        batch_mul_de = tf.matmul(h,de_var) #(b, T, d)
        batch_mul_de = tf.transpose(batch_mul_de,[0,2,1])
        e_de_list = []
        for t in range(self.time_step):
            series_t = tf.reshape(batch_mul_de[:,:,t],[self.batch_size,self.n_hidden,1])
            e_t = self.de_attention(dec_out,series_t, scope = 'decoder')
            e_de_list.append(e_t)
        e_de_list = tf.concat(e_de_list,axis = 1) # b,T,T
        de_soft_attention = tf.nn.softmax(e_de_list,dim = 1)
        #self.out = de_soft_attention
        
            # ===== context c_t ===== ##
        c_list = []
        for t in range(self.time_step):
            Beta_t = tf.expand_dims(de_soft_attention[:,:,0],-1)
            weighted = tf.reduce_sum(tf.multiply(Beta_t,h),1)
            c_list.append(tf.expand_dims(weighted,1))
        c_t = tf.concat(c_list,axis = 1) ## (b,T,d)
        self.out = c_t
        c_t_hat = tf.concat([c_t,tf.expand_dims(self.input_y,-1)],axis = 2) # b,T,(d+1), where +1 for concatenation
        
            # ===== y_hat ===== ##
        with tf.variable_scope('temporal'):
            mean = 0.0
            stddev = 1.0/(self.n_hidden*self.time_step)
            W_hat = tf.get_variable(name = 'W_hat',shape = [self.n_hidden+1,1],dtype = tf.float32,
                                    initializer=tf.truncated_normal_initializer(mean,stddev)) 
        
        W_o = tf.tile(tf.expand_dims(W_hat,0),[self.batch_size,1,1])
        y_hat = tf.matmul(c_t_hat,W_o) ## b,T,1
        
            ## ==== final step ==== ##
        d_y_concat = tf.concat([d,y_hat],axis = 2) ## b,T,q+1
        with tf.variable_scope('out_lstm') as scope:
            d_final,_ = tf.nn.dynamic_rnn(self.output_cell, d_y_concat, self.seq_len, dtype = tf.float32) # b,T,o_hidden
            
            ## ==== output y_T ==== ##
        ## only concat the last state d_T and c_T
        d_c_concat = tf.concat([d_final[:,-1,:],c_t[:,-1,:]],axis = 1) #b,o_hidden+q
        d_c_concat = tf.expand_dims(d_c_concat,-1) # b,d+q,1
        
        with tf.variable_scope('predict'):
            mean = 0.0
            stddev = 1.0/(self.n_hidden*self.time_step)
            Wy = tf.get_variable(name = 'Wy',shape = [self.o_hidden,self.o_hidden+self.n_hidden],dtype = tf.float32,
                                 initializer=tf.truncated_normal_initializer(mean,stddev)) 
            Vy = tf.get_variable(name = 'Vy',shape = [self.o_hidden],dtype = tf.float32,
                                 initializer=tf.truncated_normal_initializer(mean,stddev)) 
            bw = tf.get_variable(name = 'bw',shape = [self.o_hidden],dtype = tf.float32,
                                initializer = tf.constant_initializer(0.1))
        W_y = tf.tile(tf.expand_dims(Wy,0),[self.batch_size,1,1]) # b,q,q+d
        b_w = tf.expand_dims(tf.tile(tf.expand_dims(bw,0),[self.batch_size,1]),-1) #b,q -> b,q,1
        V_y = tf.tile(tf.expand_dims(Vy,0),[self.batch_size,1]) #b,q
        V_y = tf.expand_dims(V_y,1) #b,1,q
        self.y_predict = tf.squeeze(tf.matmul(V_y,tf.matmul(W_y,d_c_concat)+b_w)) #(b,1,q) * (b,q,1) -> squeeze -> (b,)
        
        self.loss += tf.reduce_mean(tf.square(self.label - self.y_predict))
        self.params = tf.trainable_variables()
        optimizer = tf.train.AdamOptimizer(1e-3)
        #self.train_op = optimizer.minimize(self.loss)
        grad_var = optimizer.compute_gradients(loss = self.loss, var_list = self.params, aggregation_method = 2)
        self.train_op = optimizer.apply_gradients(grad_var)
        
        
    def en_RNN(self,input_x):
        
        with tf.variable_scope('fw_lstm') as scope:
            cell = self.encode_cell  ## this step don't create variable 
            out, states = tf.nn.dynamic_rnn(cell, input_x, self.seq_len, dtype = tf.float32) ## this step does create variables
            
        tmp = tf.tile(states[1],[1,self.time_step])
        tmp = tf.reshape(tmp,[self.batch_size, self.time_step, self.n_hidden])
        
        concat = tf.concat([out,tmp],axis = 2)
        return concat ## shape shoule be (b,T,2*n_hidden)
    
    def de_RNN(self,h):
        
        with tf.variable_scope('dec_lstm') as scope:
            cell = self.decode_cell
            d,s = tf.nn.dynamic_rnn(cell, h, self.seq_len, dtype = tf.float32)
        tmp = tf.tile(s[1],[1,self.time_step])
        tmp = tf.reshape(tmp,[self.batch_size, self.time_step, self.d_hidden])
        concat = tf.concat([d,tmp],axis = 2)
        return d,concat
        
    def attention(self, out, series_k, scope = None):
   
        with tf.variable_scope('encoder') as scope:
            try:
                mean = 0.0
                stddev = 1.0/(self.n_hidden*self.time_step)
                We = tf.get_variable(name = 'We', dtype=tf.float32,shape = [self.time_step, 2*self.n_hidden],
                                     initializer=tf.truncated_normal_initializer(mean,stddev))
                Ve = tf.get_variable(name = 'Ve',dtype=tf.float32,shape = [1,self.time_step],
                                     initializer=tf.truncated_normal_initializer(mean,stddev))
            except ValueError:
                scope.reuse_variables()
                We = tf.get_variable('We')
                Ve = tf.get_variable('Ve')       
        W_e = tf.tile(tf.expand_dims(We,0),[self.batch_size,1,1])  # b*T*2d
        brcast = tf.nn.tanh(tf.matmul(W_e,out) + series_k) # b,T,T + b,T,1 = b, T, T
        V_e = tf.tile(tf.expand_dims(Ve,0),[self.batch_size,1,1]) # b,1,T
        
        return tf.matmul(V_e,brcast) # b,1,T
    
    def de_attention(self,out,series_k,scope = None):
        
        with tf.variable_scope('decoder') as scope:
            try:
                mean = 0.0
                stddev = 1.0/(self.d_hidden*self.time_step)
                Wd = tf.get_variable(name = 'Wd', dtype=tf.float32,shape = [self.n_hidden, 2*self.d_hidden],
                                     initializer=tf.truncated_normal_initializer(mean,stddev))
                Vd = tf.get_variable(name = 'Vd',dtype=tf.float32,shape = [1,self.n_hidden],
                                     initializer=tf.truncated_normal_initializer(mean,stddev))
            except ValueError:
                scope.reuse_variables()
                Wd = tf.get_variable('Wd')
                Vd = tf.get_variable('Vd') 
        W_d = tf.tile(tf.expand_dims(Wd,0),[self.batch_size,1,1])
        brcast = tf.nn.tanh(tf.matmul(W_d,out) + series_k) # b,d,2q * b,2q*T = b,d,T
        #return brcast
        V_d = tf.tile(tf.expand_dims(Vd,0),[self.batch_size,1,1]) # b,1,d
        
        return tf.matmul(V_d,brcast) # b,1,d * b,d,T = b,1,T
    
    def predict(self,x_test,y_test,sess):
        
        train_seq_len =  np.ones(self.batch_size) * self.time_step
        feed = {model.input_x: x_test, 
                model.seq_len: train_seq_len,
                model.input_y: y_test}
        y_hat = sess.run(self.y_predict,feed_dict = feed)
        return y_hat

# %%
batch_size = 256
train_batch_num = int(len(df1)*0.8/batch_size) ## 0.8 of traininng data, 20% for testing
df_test = df1[(train_batch_num*batch_size):]
df1 = df1[:(train_batch_num*batch_size)+65]

# %%
batch_size = 256
INPUT_DIM = 6 # six input feature
time_step = 48 # 12 consecutive data to predict next one
n_hidden = 128 # encoder dim
d_hidden = 64 # decoder dim

## o_hidden = 16 default

current_episode = 0
total_episodes = 100
steps = int(len(df1)/batch_size)

tf.reset_default_graph()

model = ts_prediction(input_dim = 6, time_step = time_step, n_hidden= n_hidden, d_hidden = d_hidden, batch_size = batch_size)
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

while current_episode<=total_episodes:
    cumulative_loss = 0.0
    for t in range(steps):
        
        x,y,labels = get_batch(df1,batch_size = batch_size, T = time_step, step = t)
        
        train_seq_len =  np.ones(batch_size) * time_step
        feed = {model.input_x: x, 
                model.seq_len: train_seq_len,
                model.input_y: y,
                model.label: labels}
        loss,_ = sess.run([model.loss,model.train_op],feed_dict = feed)
        cumulative_loss += loss
        if t%10==0:
            print "current_episode %i, steps %i, losses are %f" % ( current_episode, t, cumulative_loss)
            cumulative_loss = 0.0
    current_episode+=1
    #loss = sess.run(model.out,feed_dict = feed)

# %%
x_test,y_test,labels_test = get_batch(df1[-150:],batch_size = batch_size, T = time_step, step = 0)

# %%
steps_test = int(len(df_test)/batch_size)
test_loss = 0.0
for t in range(steps_test-1):

    x_test,y_test,labels_test = get_batch(df_test,batch_size = batch_size, T = time_step, step = t) 
    
    y_hat = model.predict(x_test,y_test,sess) - labels_test
    test_loss += np.mean(np.square(y_hat))

print "the mean squared error for test data are %f " % (test_loss*1.0/steps_test)
#     train_seq_len =  np.ones(batch_size) * time_step
#     feed = {model.input_x: x, 
#             model.seq_len: train_seq_len,
#             model.input_y: y,
#             model.label: labels}
#     loss,_ = sess.run([model.loss,model.train_op],feed_dict = feed)
# Out:
# the mean squared error for test data are 2.347517

# %%
## batch_size 256
steps_test = int(len(df_test)/batch_size)
test_loss = 0.0
for t in range(steps_test-1):

    x_test,y_test,labels_test = get_batch(df_test,batch_size = batch_size, T = time_step, step = t) 
    
    y_hat = model.predict(x_test,y_test,sess) - labels_test
    test_loss += np.mean(np.square(y_hat))

print "the mean squared error for test data are %f " % (test_loss*1.0/steps_test)
#     train_seq_len =  np.ones(batch_size) * time_step
#     feed = {model.input_x: x, 
#             model.seq_len: train_seq_len,
#             model.input_y: y,
#             model.label: labels}
#     loss,_ = sess.run([model.loss,model.train_op],feed_dict = feed)
# Out:
# the mean squared error for test data are 1.635238

# %% [markdown]
# ### Model Version 2
# + Change of decode RNN, instead of 2 decoding lstm, but decoder share one lstm  $f_{2}$

# %%
class ts_prediction(object):
    
    def __init__(self, input_dim, time_step, n_hidden, d_hidden, batch_size):

        self.batch_size = batch_size
        self.n_hidden = n_hidden
        self.d_hidden = d_hidden
        #self.o_hidden = 16
        
        self.input_dim = input_dim
        self.time_step = time_step
        
        self.seq_len = tf.placeholder(tf.int32,[None])
        self.input_x = tf.placeholder(dtype = tf.float32, shape = [None, None, input_dim]) # b,T,d_in
        self.input_y = tf.placeholder(dtype = tf.float32,shape = [None,self.time_step]) # b,T
        self.label = tf.placeholder(dtype = tf.float32) #b,1
        
        self.encode_cell = tf.contrib.rnn.LSTMCell(self.n_hidden, forget_bias=1.0, state_is_tuple=True)
        self.decode_cell = tf.contrib.rnn.LSTMCell(self.d_hidden, forget_bias=1.0, state_is_tuple=True)
        #self.output_cell = tf.contrib.rnn.LSTMCell(self.o_hidden, forget_bias=1.0, state_is_tuple=True)
        
        self.loss = tf.constant(0.0)
            ## ===========  build the model =========== ##
            
            ## ==== encoder ===== ## 
        h_encode, c_state = self.en_RNN(self.input_x)
        c_expand = tf.tile(tf.expand_dims(c_state[1],1),[1,self.time_step,1])
        fw_lstm = tf.concat([h_encode,c_expand],axis = 2) # b,T,2n
        stddev = 1.0/(self.n_hidden*self.time_step)
        Ue = tf.get_variable(name= 'Ue',dtype = tf.float32,
                             initializer = tf.truncated_normal(mean = 0.0, stddev = stddev,shape = [self.time_step,self.time_step]))
        ## (b,d,T) * (b,T,T)  = (b,d,T)
        brcast_UX = tf.matmul(tf.transpose(self.input_x,[0,2,1]),tf.tile(tf.expand_dims(Ue,0),[self.batch_size,1,1]))
        e_list = []
        for k in range(self.input_dim):
            feature_k = brcast_UX[:,k,:] 
            e_k = self.en_attention(fw_lstm,feature_k) # b,T 
            e_list.append(e_k)
        e_mat = tf.concat(e_list,axis = 2)
        alpha_mat = tf.nn.softmax(e_mat) #b,T,d_in
        encode_input = tf.multiply(self.input_x,alpha_mat)
        h_t, c_t = self.en_RNN(encode_input, scopes = 'fw_lstm')
        
        
        h_decode, d_state = self.de_RNN(tf.expand_dims(self.input_y,-1))
        
        d_expand = tf.tile(tf.expand_dims(d_state[1],1),[1,self.time_step,1])
        dec_lstm = tf.concat([h_decode,d_expand],axis = 2) # b,T,2*d_hidden

        Ud = tf.get_variable(name = 'Ud', dtype = tf.float32,
                             initializer = tf.truncated_normal(mean = 0.0, stddev = stddev, shape = [self.n_hidden, self.n_hidden]))
        
        brcast_UDX = tf.matmul(h_t,tf.tile(tf.expand_dims(Ud,0),[self.batch_size,1,1])) # b,T,n_hidden
        
        l_list = []
        for i in range(self.time_step):
            feature_i = brcast_UDX[:,i,:]
            l_i = self.dec_attention(dec_lstm,feature_i)
            l_list.append(l_i)
        l_mat = tf.concat(l_list,axis = 2)
        beta_mat = tf.nn.softmax(l_mat, dim = 1)
        context_list = []
        h_tmp = tf.transpose(h_t,[0,2,1])

        for t in range(self.time_step):
            beta_t = tf.reshape(beta_mat[:,t,:],[self.batch_size,1,self.time_step])
            c_t = tf.reduce_sum(tf.multiply(h_tmp,beta_t),2) # b,T,T -> b,T,1
            context_list.append(c_t)
        c_context = tf.stack(context_list,axis = 2) # b,n_hidden,T
        # b,T,1 b,T,n_hidden -> b,T,n_hidden+1
        c_concat = tf.concat([tf.expand_dims(self.input_y,-1),tf.transpose(c_context,[0,2,1])], axis = 2)
        W_hat = tf.get_variable(name = 'W_hat', dtype = tf.float32,
                                initializer = tf.truncated_normal(mean = 0.0, stddev = stddev,shape = [self.n_hidden+1,1]))
        y_encode = tf.matmul(c_concat,tf.tile(tf.expand_dims(W_hat,0),[self.batch_size,1,1]))
        
        
        h_out, d_out = self.de_RNN(y_encode)
        
        last_concat = tf.expand_dims(tf.concat([h_out[:,-1,:],d_out[-1]],axis = 1),1)
        Wy = tf.get_variable(name = 'Wy', dtype = tf.float32,initializer = tf.truncated_normal(mean = 0.0, stddev = stddev,shape = [self.n_hidden+self.d_hidden,1]))
        W_y = tf.tile(tf.expand_dims(Wy,0),[self.batch_size,1,1])
        self.y_predict = tf.squeeze(tf.matmul(last_concat,W_y))
        self.loss += tf.reduce_mean(tf.square(self.label - self.y_predict)) # reduce_mean: avg of batch loss
        self.params = tf.trainable_variables()
        optimizer = tf.train.AdamOptimizer(1e-3)
        #self.train_op = optimizer.minimize(self.loss)
        grad_var = optimizer.compute_gradients(loss = self.loss, var_list = self.params, aggregation_method = 2)
        self.train_op = optimizer.apply_gradients(grad_var)
        
        
    def en_RNN(self, input_x, scopes = 'fw_lstm'):
        '''
        input_x: b, T, d_in
        
        output: h:       seqence of output state b,T,n_hidden
                state:   final state b,n_hidden
                
        '''
        with tf.variable_scope('fw_lstm' or scopes) as scope:
            try:
                h,state = tf.nn.dynamic_rnn(
                    cell = self.encode_cell, inputs = input_x,
                    sequence_length = self.seq_len,
                    dtype = tf.float32, scope = 'fw_lstm')
                
            except ValueError:
                scope.reuse_variables()
                h,state = tf.nn.dynamic_rnn(
                    cell = self.encode_cell, inputs = input_x,
                    sequence_length = self.seq_len,
                    dtype = tf.float32, scope = scopes)
        
        return [h,state]
    
    def de_RNN(self,input_y, scopes = 'de_lstm'):
        
        with tf.variable_scope('dec_lstm') as scope:
            try:
                h,state = tf.nn.dynamic_rnn(
                    cell = self.decode_cell, inputs = input_y,
                    sequence_length = self.seq_len,
                    dtype = tf.float32, scope = 'de_lstm')
                
            except ValueError:
                scope.reuse_variables()
                h,state = tf.nn.dynamic_rnn(
                    cell = self.decode_cell, inputs = input_y,
                    sequence_length = self.seq_len,
                    dtype = tf.float32, scope = scopes)
        
        return [h,state]
    
    def en_attention(self,fw_lstm,feature_k):
        '''
        fw_lstm: b,T,2n
        feature_k: row k from brcast_UX, b,T
        
        return: b,T
        '''
        with tf.variable_scope('encoder') as scope:
            try:
                mean = 0.0
                stddev = 1.0/(self.n_hidden*self.time_step)
                We = tf.get_variable(name = 'We', dtype=tf.float32,shape = [self.time_step, 2*self.n_hidden],
                                     initializer=tf.truncated_normal_initializer(mean,stddev))
                Ve = tf.get_variable(name = 'Ve',dtype=tf.float32,shape = [self.time_step,1],
                                     initializer=tf.truncated_normal_initializer(mean,stddev))
            except ValueError:
                scope.reuse_variables()
                We = tf.get_variable('We')
                Ve = tf.get_variable('Ve')   
            # (b,T,2n) (b,2n,T)
        W_e = tf.transpose(tf.tile(tf.expand_dims(We,0),[self.batch_size,1,1]),[0,2,1]) # b,2n,T
        mlp = tf.nn.tanh(tf.matmul(fw_lstm,W_e) + tf.reshape(feature_k,[self.batch_size,1,self.time_step])) #b,T,T + b,1,T = b,T,T
        V_e = tf.tile(tf.expand_dims(Ve,0),[self.batch_size,1,1])
        return  tf.matmul(mlp,V_e)
            
    def dec_attention(self, dec_lstm, feature_t, scopes = None):
        '''
        dec_lstm: b,T,2*d_hidden
        feature_k: row k from brcast_UX, b,T
        
        return: b,T
        '''
        with tf.variable_scope('decoder' or scopes) as scope:
            try:
                mean = 0.0
                stddev = 1.0/(self.n_hidden*self.time_step)
                Wd = tf.get_variable(name = 'Wd', dtype=tf.float32, shape = [self.n_hidden, 2*self.d_hidden],
                                     initializer=tf.truncated_normal_initializer(mean,stddev))
                Vd = tf.get_variable(name = 'Vd', dtype=tf.float32, shape = [self.n_hidden,1],
                                     initializer=tf.truncated_normal_initializer(mean,stddev))
            except ValueError:
                scope.reuse_variables()
                Wd = tf.get_variable('Wd')
                Vd = tf.get_variable('Vd')   
        # (b,T,2*d_hidden) (b,2*d_hidden,T)
        W_d = tf.transpose(tf.tile(tf.expand_dims(Wd,0),[self.batch_size,1,1]),[0,2,1]) # b,2*d_hidden,n_hidden
        # (b,T,2*d_hidden) * (b,2*d_hidden,n_hidden) -> b,T,n_hidden
        mlp = tf.nn.tanh(tf.matmul(dec_lstm,W_d) + tf.reshape(feature_t,[self.batch_size,1,self.n_hidden])) #b,T,n_hidden + b,1,n_hidden = b,T,n_hidden
        V_d = tf.tile(tf.expand_dims(Vd,0),[self.batch_size,1,1])
        return  tf.matmul(mlp,V_d) #b,T,1
    
    def predict(self,x_test,y_test,sess):
        
        train_seq_len =  np.ones(self.batch_size) * self.time_step
        feed = {model.input_x: x_test, 
                model.seq_len: train_seq_len,
                model.input_y: y_test}
        y_hat = sess.run(self.y_predict,feed_dict = feed)
        return y_hat

# %%
batch_size = 256
train_batch_num = int(len(df1)*0.8/batch_size) ## 0.8 of traininng data, 20% for testing

df_test = df1[(train_batch_num*batch_size):]
df1 = df1[:(train_batch_num*batch_size)+65]

print 'Training data %i' % len(df1), "testing data %i" % len(df_test)
# Out:
# Training data 22081 testing data 5518

# %%
batch_size = 256
INPUT_DIM = 6 # six input feature
time_step = 48 # 12 consecutive data to predict next one
n_hidden = 64 # encoder dim
d_hidden = 64 # decoder dim
## o_hidden = 16 default

current_episode = 0
total_episodes = 50
steps = int(len(df1)/batch_size)

tf.reset_default_graph()

model = ts_prediction(input_dim = 6, time_step = time_step, n_hidden= n_hidden, d_hidden = d_hidden, batch_size = batch_size)
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

while current_episode<=total_episodes:
    cumulative_loss = 0.0
#     index = range(train_batch_num*batch_size)
#     np.random.shuffle(index)
#     df1 = df1.iloc[index]
    
    for t in range(steps):
        ## shuffle the batch
        index = range(x.shape[0])
        np.random.shuffle(index)
        x,y,labels = get_batch(df1,batch_size = batch_size, T = time_step, step = t)
        train_seq_len =  np.ones(batch_size) * time_step
        feed = {model.input_x: x, 
                model.seq_len: train_seq_len,
                model.input_y: y,
                model.label: labels}
        loss,_ = sess.run([model.loss,model.train_op],feed_dict = feed)
        cumulative_loss += loss
        if t%10==0:
            print "current_episode %i, steps %i, losses are %f" % ( current_episode, t, cumulative_loss)
            cumulative_loss = 0.0
    current_episode+=1
# Out:
# current_episode 0, steps 0, losses are 625.612000
# current_episode 0, steps 10, losses are 5811.275665
# current_episode 0, steps 20, losses are 1096.874462
# current_episode 0, steps 30, losses are 840.760548
# current_episode 0, steps 40, losses are 3802.431320
# current_episode 0, steps 50, losses are 2477.973988
# current_episode 0, steps 60, losses are 811.771133
# current_episode 0, steps 70, losses are 419.734690
# current_episode 0, steps 80, losses are 1795.797066
# current_episode 1, steps 0, losses are 273.238586
# current_episode 1, steps 10, losses are 2245.366516
# current_episode 1, steps 20, losses are 534.851821
# current_episode 1, steps 30, losses are 563.696776
# current_episode 1, steps 40, losses are 1502.484596
# current_episode 1, steps 50, losses are 945.645264
# current_episode 1, steps 60, losses are 1671.222445
# current_episode 1, steps 70, losses are 911.728844
# current_episode 1, steps 80, losses are 998.022505
# current_episode 2, steps 0, losses are 170.616272
# current_episode 2, steps 10, losses are 1401.852013
# current_episode 2, steps 20, losses are 755.261297
# current_episode 2, steps 30, losses are 798.105239
# current_episode 2, steps 40, losses are 1091.721621
# current_episode 2, steps 50, losses are 681.123156
# current_episode 2, steps 60, losses are 2056.341402
# current_episode 2, steps 70, losses are 1156.342312
# current_episode 2, steps 80, losses are 717.820728
# current_episode 3, steps 0, losses are 142.319534
# current_episode 3, steps 10, losses are 1184.012878
# current_episode 3, steps 20, losses are 834.102734
# current_episode 3, steps 30, losses are 781.765443
# current_episode 3, steps 40, losses are 1153.190483
# current_episode 3, steps 50, losses are 697.778606
# current_episode 3, steps 60, losses are 1869.543062
# current_episode 3, steps 70, losses are 707.036522
# current_episode 3, steps 80, losses are 889.687361
# current_episode 4, steps 0, losses are 132.671783
# current_episode 4, steps 10, losses are 1033.071682
# current_episode 4, steps 20, losses are 266.237429
# current_episode 4, steps 30, losses are 171.811686
# current_episode 4, steps 40, losses are 811.928471
# current_episode 4, steps 50, losses are 453.858082
# current_episode 4, steps 60, losses are 319.385917
# current_episode 4, steps 70, losses are 210.112249
# current_episode 4, steps 80, losses are 314.923598
# current_episode 5, steps 0, losses are 64.440979
# current_episode 5, steps 10, losses are 534.426824
# current_episode 5, steps 20, losses are 228.999247
# current_episode 5, steps 30, losses are 125.210496
# current_episode 5, steps 40, losses are 413.524257
# current_episode 5, steps 50, losses are 227.093763
# current_episode 5, steps 60, losses are 198.625787
# current_episode 5, steps 70, losses are 136.698204
# current_episode 5, steps 80, losses are 173.619167
# current_episode 6, steps 0, losses are 32.690311
# current_episode 6, steps 10, losses are 310.163682
# current_episode 6, steps 20, losses are 318.298109
# current_episode 6, steps 30, losses are 191.991364
# current_episode 6, steps 40, losses are 361.314440
# current_episode 6, steps 50, losses are 226.208182
# current_episode 6, steps 60, losses are 210.491419
# current_episode 6, steps 70, losses are 129.393508
# current_episode 6, steps 80, losses are 149.262532
# current_episode 7, steps 0, losses are 26.844522
# current_episode 7, steps 10, losses are 255.941846
# current_episode 7, steps 20, losses are 192.748667
# current_episode 7, steps 30, losses are 112.338027
# current_episode 7, steps 40, losses are 207.810553
# current_episode 7, steps 50, losses are 125.889391
# current_episode 7, steps 60, losses are 132.173396
# current_episode 7, steps 70, losses are 80.054800
# current_episode 7, steps 80, losses are 86.952144
# current_episode 8, steps 0, losses are 16.310480
# current_episode 8, steps 10, losses are 173.082761
# current_episode 8, steps 20, losses are 95.816815
# current_episode 8, steps 30, losses are 61.762788
# current_episode 8, steps 40, losses are 139.198397
# current_episode 8, steps 50, losses are 86.672371
# current_episode 8, steps 60, losses are 113.573798
# current_episode 8, steps 70, losses are 69.053754
# current_episode 8, steps 80, losses are 72.443364
# current_episode 9, steps 0, losses are 10.694524
# current_episode 9, steps 10, losses are 132.030470
# current_episode 9, steps 20, losses are 99.767569
# current_episode 9, steps 30, losses are 104.599216
# current_episode 9, steps 40, losses are 116.750322
# current_episode 9, steps 50, losses are 116.914614
# current_episode 9, steps 60, losses are 134.545593
# current_episode 9, steps 70, losses are 78.286933
# current_episode 9, steps 80, losses are 102.265193
# current_episode 10, steps 0, losses are 8.876349
# current_episode 10, steps 10, losses are 131.320073
# current_episode 10, steps 20, losses are 136.897440
# current_episode 10, steps 30, losses are 76.964701
# current_episode 10, steps 40, losses are 116.737102
# current_episode 10, steps 50, losses are 94.809580
# current_episode 10, steps 60, losses are 91.961797
# current_episode 10, steps 70, losses are 56.101072
# current_episode 10, steps 80, losses are 67.822695
# current_episode 11, steps 0, losses are 7.839098
# current_episode 11, steps 10, losses are 100.777583
# current_episode 11, steps 20, losses are 88.278208
# current_episode 11, steps 30, losses are 73.466072
# current_episode 11, steps 40, losses are 94.577915
# current_episode 11, steps 50, losses are 76.189076
# current_episode 11, steps 60, losses are 80.857169
# current_episode 11, steps 70, losses are 52.401169
# current_episode 11, steps 80, losses are 67.516437
# current_episode 12, steps 0, losses are 6.381283
# current_episode 12, steps 10, losses are 90.105022
# current_episode 12, steps 20, losses are 80.102209
# current_episode 12, steps 30, losses are 60.088409
# current_episode 12, steps 40, losses are 88.844099
# current_episode 12, steps 50, losses are 65.289575
# current_episode 12, steps 60, losses are 76.791202
# current_episode 12, steps 70, losses are 38.855806
# current_episode 12, steps 80, losses are 50.916843
# current_episode 13, steps 0, losses are 5.480259
# current_episode 13, steps 10, losses are 73.926300
# current_episode 13, steps 20, losses are 49.066603
# current_episode 13, steps 30, losses are 37.860078
# current_episode 13, steps 40, losses are 64.034565
# current_episode 13, steps 50, losses are 48.172666
# current_episode 13, steps 60, losses are 64.825754
# current_episode 13, steps 70, losses are 37.234554
# current_episode 13, steps 80, losses are 39.892226
# current_episode 14, steps 0, losses are 4.679381
# current_episode 14, steps 10, losses are 63.478691
# current_episode 14, steps 20, losses are 51.138310
# current_episode 14, steps 30, losses are 37.833177
# current_episode 14, steps 40, losses are 56.097097
# current_episode 14, steps 50, losses are 45.450852
# current_episode 14, steps 60, losses are 61.710959
# current_episode 14, steps 70, losses are 30.124388
# current_episode 14, steps 80, losses are 41.851496
# current_episode 15, steps 0, losses are 4.462670
# current_episode 15, steps 10, losses are 62.924034
# current_episode 15, steps 20, losses are 48.603369
# current_episode 15, steps 30, losses are 36.331288
# current_episode 15, steps 40, losses are 59.771461
# current_episode 15, steps 50, losses are 50.107364
# current_episode 15, steps 60, losses are 62.463428
# current_episode 15, steps 70, losses are 35.660909
# current_episode 15, steps 80, losses are 47.474074
# current_episode 16, steps 0, losses are 4.183163
# current_episode 16, steps 10, losses are 63.636945
# current_episode 16, steps 20, losses are 60.222720
# current_episode 16, steps 30, losses are 45.045791
# current_episode 16, steps 40, losses are 68.453875
# current_episode 16, steps 50, losses are 57.787061
# current_episode 16, steps 60, losses are 66.452492
# current_episode 16, steps 70, losses are 35.029829
# current_episode 16, steps 80, losses are 40.150428
# current_episode 17, steps 0, losses are 2.829214
# current_episode 17, steps 10, losses are 44.937794
# current_episode 17, steps 20, losses are 52.148071
# current_episode 17, steps 30, losses are 38.153824
# current_episode 17, steps 40, losses are 60.727902
# current_episode 17, steps 50, losses are 50.805962
# current_episode 17, steps 60, losses are 54.415174
# current_episode 17, steps 70, losses are 25.523454
# current_episode 17, steps 80, losses are 35.707446
# current_episode 18, steps 0, losses are 2.634708
# current_episode 18, steps 10, losses are 45.528704
# current_episode 18, steps 20, losses are 41.588245
# current_episode 18, steps 30, losses are 28.020427
# current_episode 18, steps 40, losses are 78.214162
# current_episode 18, steps 50, losses are 52.191465
# current_episode 18, steps 60, losses are 50.871670
# current_episode 18, steps 70, losses are 24.093195
# current_episode 18, steps 80, losses are 36.765455
# current_episode 19, steps 0, losses are 2.442288
# current_episode 19, steps 10, losses are 37.793861
# current_episode 19, steps 20, losses are 38.202838
# current_episode 19, steps 30, losses are 27.254487
# current_episode 19, steps 40, losses are 44.963724
# current_episode 19, steps 50, losses are 34.265817
# current_episode 19, steps 60, losses are 50.635798
# current_episode 19, steps 70, losses are 21.743779
# current_episode 19, steps 80, losses are 29.601266
# current_episode 20, steps 0, losses are 2.050594
# current_episode 20, steps 10, losses are 34.737330
# current_episode 20, steps 20, losses are 34.282287
# current_episode 20, steps 30, losses are 25.030823
# current_episode 20, steps 40, losses are 37.082895
# current_episode 20, steps 50, losses are 29.804465
# current_episode 20, steps 60, losses are 44.732286
# current_episode 20, steps 70, losses are 21.218691
# current_episode 20, steps 80, losses are 22.862492
# current_episode 21, steps 0, losses are 1.695331
# current_episode 21, steps 10, losses are 29.396831
# current_episode 21, steps 20, losses are 29.451464
# current_episode 21, steps 30, losses are 20.919406
# current_episode 21, steps 40, losses are 37.588608
# current_episode 21, steps 50, losses are 28.423777
# current_episode 21, steps 60, losses are 40.184210
# current_episode 21, steps 70, losses are 19.240672
# current_episode 21, steps 80, losses are 20.917315
# current_episode 22, steps 0, losses are 1.488969
# current_episode 22, steps 10, losses are 26.715537
# current_episode 22, steps 20, losses are 27.728519
# current_episode 22, steps 30, losses are 18.296823
# current_episode 22, steps 40, losses are 34.206563
# current_episode 22, steps 50, losses are 26.476439
# current_episode 22, steps 60, losses are 39.740920
# current_episode 22, steps 70, losses are 18.597904
# current_episode 22, steps 80, losses are 18.655054
# current_episode 23, steps 0, losses are 1.333996
# current_episode 23, steps 10, losses are 24.560809
# current_episode 23, steps 20, losses are 26.202583
# current_episode 23, steps 30, losses are 18.064497
# current_episode 23, steps 40, losses are 26.793463
# current_episode 23, steps 50, losses are 22.158208
# current_episode 23, steps 60, losses are 34.940311
# current_episode 23, steps 70, losses are 17.009615
# current_episode 23, steps 80, losses are 21.438770
# current_episode 24, steps 0, losses are 1.325158
# current_episode 24, steps 10, losses are 25.256017
# current_episode 24, steps 20, losses are 24.085599
# current_episode 24, steps 30, losses are 15.872680
# current_episode 24, steps 40, losses are 24.804934
# current_episode 24, steps 50, losses are 22.257848
# current_episode 24, steps 60, losses are 31.316624
# current_episode 24, steps 70, losses are 14.746284
# current_episode 24, steps 80, losses are 18.534695
# current_episode 25, steps 0, losses are 1.206167
# current_episode 25, steps 10, losses are 21.500711
# current_episode 25, steps 20, losses are 23.069089
# current_episode 25, steps 30, losses are 15.697014
# current_episode 25, steps 40, losses are 18.559705
# current_episode 25, steps 50, losses are 18.067853
# current_episode 25, steps 60, losses are 29.684545
# current_episode 25, steps 70, losses are 14.455054
# current_episode 25, steps 80, losses are 17.808814
# current_episode 26, steps 0, losses are 1.269046
# current_episode 26, steps 10, losses are 19.447697
# current_episode 26, steps 20, losses are 21.731646
# current_episode 26, steps 30, losses are 14.952996
# current_episode 26, steps 40, losses are 17.297924
# current_episode 26, steps 50, losses are 17.819458
# current_episode 26, steps 60, losses are 27.332569
# current_episode 26, steps 70, losses are 13.524590
# current_episode 26, steps 80, losses are 17.471007
# current_episode 27, steps 0, losses are 1.388325
# current_episode 27, steps 10, losses are 18.025048
# current_episode 27, steps 20, losses are 20.613906
# current_episode 27, steps 30, losses are 13.659608
# current_episode 27, steps 40, losses are 16.337326
# current_episode 27, steps 50, losses are 16.146927
# current_episode 27, steps 60, losses are 27.506892
# current_episode 27, steps 70, losses are 13.390962
# current_episode 27, steps 80, losses are 15.001289
# current_episode 28, steps 0, losses are 1.144158
# current_episode 28, steps 10, losses are 17.726400
# current_episode 28, steps 20, losses are 21.842778
# current_episode 28, steps 30, losses are 14.986293
# current_episode 28, steps 40, losses are 15.087466
# current_episode 28, steps 50, losses are 14.340543
# current_episode 28, steps 60, losses are 27.400341
# current_episode 28, steps 70, losses are 13.106563
# current_episode 28, steps 80, losses are 13.286494
# current_episode 29, steps 0, losses are 0.954603
# current_episode 29, steps 10, losses are 14.922607
# current_episode 29, steps 20, losses are 18.177890
# current_episode 29, steps 30, losses are 12.959258
# current_episode 29, steps 40, losses are 13.315122
# current_episode 29, steps 50, losses are 13.017348
# current_episode 29, steps 60, losses are 23.018755
# current_episode 29, steps 70, losses are 12.064504
# current_episode 29, steps 80, losses are 11.276417
# current_episode 30, steps 0, losses are 0.852090
# current_episode 30, steps 10, losses are 14.371278
# current_episode 30, steps 20, losses are 19.518866
# current_episode 30, steps 30, losses are 17.168329
# current_episode 30, steps 40, losses are 12.707954
# current_episode 30, steps 50, losses are 16.644054
# current_episode 30, steps 60, losses are 27.518743
# current_episode 30, steps 70, losses are 15.083280
# current_episode 30, steps 80, losses are 17.525879
# current_episode 31, steps 0, losses are 0.967355
# current_episode 31, steps 10, losses are 17.610288
# current_episode 31, steps 20, losses are 27.952406
# current_episode 31, steps 30, losses are 23.877089
# current_episode 31, steps 40, losses are 16.450155
# current_episode 31, steps 50, losses are 26.617319
# current_episode 31, steps 60, losses are 31.237734
# current_episode 31, steps 70, losses are 16.291407
# current_episode 31, steps 80, losses are 25.765451
# current_episode 32, steps 0, losses are 1.155545
# current_episode 32, steps 10, losses are 20.589170
# current_episode 32, steps 20, losses are 33.328993
# current_episode 32, steps 30, losses are 23.539488
# current_episode 32, steps 40, losses are 37.666435
# current_episode 32, steps 50, losses are 38.460766
# current_episode 32, steps 60, losses are 32.638333
# current_episode 32, steps 70, losses are 17.722421
# current_episode 32, steps 80, losses are 49.047678
# current_episode 33, steps 0, losses are 1.699096
# current_episode 33, steps 10, losses are 29.920606
# current_episode 33, steps 20, losses are 34.874989
# current_episode 33, steps 30, losses are 20.844085
# current_episode 33, steps 40, losses are 63.016330
# current_episode 33, steps 50, losses are 55.035067
# current_episode 33, steps 60, losses are 26.371770
# current_episode 33, steps 70, losses are 17.368916
# current_episode 33, steps 80, losses are 32.692844
# current_episode 34, steps 0, losses are 1.035878
# current_episode 34, steps 10, losses are 21.501436
# current_episode 34, steps 20, losses are 36.944812
# current_episode 34, steps 30, losses are 19.811449
# current_episode 34, steps 40, losses are 36.921241
# current_episode 34, steps 50, losses are 30.492745
# current_episode 34, steps 60, losses are 19.399558
# current_episode 34, steps 70, losses are 10.345155
# current_episode 34, steps 80, losses are 22.616785
# current_episode 35, steps 0, losses are 1.452951
# current_episode 35, steps 10, losses are 17.937885
# current_episode 35, steps 20, losses are 16.981089
# current_episode 35, steps 30, losses are 9.510147
# current_episode 35, steps 40, losses are 25.391299
# current_episode 35, steps 50, losses are 21.796965
# current_episode 35, steps 60, losses are 15.904847
# current_episode 35, steps 70, losses are 7.583171
# current_episode 35, steps 80, losses are 16.197876
# current_episode 36, steps 0, losses are 0.845721
# current_episode 36, steps 10, losses are 15.549424
# current_episode 36, steps 20, losses are 14.623178
# current_episode 36, steps 30, losses are 8.667332
# current_episode 36, steps 40, losses are 14.796570
# current_episode 36, steps 50, losses are 14.342500
# current_episode 36, steps 60, losses are 14.804223
# current_episode 36, steps 70, losses are 7.637887
# current_episode 36, steps 80, losses are 11.265860
# current_episode 37, steps 0, losses are 0.736772
# current_episode 37, steps 10, losses are 11.852194
# current_episode 37, steps 20, losses are 13.125797
# current_episode 37, steps 30, losses are 7.622355
# current_episode 37, steps 40, losses are 11.821282
# current_episode 37, steps 50, losses are 12.644292
# current_episode 37, steps 60, losses are 16.534474
# current_episode 37, steps 70, losses are 8.906176
# current_episode 37, steps 80, losses are 8.836189
# current_episode 38, steps 0, losses are 0.635313
# current_episode 38, steps 10, losses are 11.441095
# current_episode 38, steps 20, losses are 13.460089
# current_episode 38, steps 30, losses are 9.848536
# current_episode 38, steps 40, losses are 11.311454
# current_episode 38, steps 50, losses are 11.892868
# current_episode 38, steps 60, losses are 15.313244
# current_episode 38, steps 70, losses are 8.012316
# current_episode 38, steps 80, losses are 9.406767
# current_episode 39, steps 0, losses are 0.616700
# current_episode 39, steps 10, losses are 10.839249
# current_episode 39, steps 20, losses are 12.270350
# current_episode 39, steps 30, losses are 7.300307
# current_episode 39, steps 40, losses are 9.485957
# current_episode 39, steps 50, losses are 10.694643
# current_episode 39, steps 60, losses are 13.087524
# current_episode 39, steps 70, losses are 6.856065
# current_episode 39, steps 80, losses are 8.718376
# current_episode 40, steps 0, losses are 0.614300
# current_episode 40, steps 10, losses are 10.278564
# current_episode 40, steps 20, losses are 11.591588
# current_episode 40, steps 30, losses are 7.268468
# current_episode 40, steps 40, losses are 9.572403
# current_episode 40, steps 50, losses are 10.881953
# current_episode 40, steps 60, losses are 12.276264
# current_episode 40, steps 70, losses are 6.114367
# current_episode 40, steps 80, losses are 8.119470
# current_episode 41, steps 0, losses are 0.598381
# current_episode 41, steps 10, losses are 10.135462
# current_episode 41, steps 20, losses are 11.546685
# current_episode 41, steps 30, losses are 7.144219
# current_episode 41, steps 40, losses are 8.866146
# current_episode 41, steps 50, losses are 10.254416
# current_episode 41, steps 60, losses are 14.818571
# current_episode 41, steps 70, losses are 6.484955
# current_episode 41, steps 80, losses are 7.707805
# current_episode 42, steps 0, losses are 0.609995
# current_episode 42, steps 10, losses are 10.218072
# current_episode 42, steps 20, losses are 11.240856
# current_episode 42, steps 30, losses are 8.703364
# current_episode 42, steps 40, losses are 8.891358
# current_episode 42, steps 50, losses are 10.623584
# current_episode 42, steps 60, losses are 12.051381
# current_episode 42, steps 70, losses are 7.067564
# current_episode 42, steps 80, losses are 9.649889
# current_episode 43, steps 0, losses are 0.666325
# current_episode 43, steps 10, losses are 10.419304
# current_episode 43, steps 20, losses are 12.034637
# current_episode 43, steps 30, losses are 8.255852
# current_episode 43, steps 40, losses are 9.485339
# current_episode 43, steps 50, losses are 11.859176
# current_episode 43, steps 60, losses are 11.166308
# current_episode 43, steps 70, losses are 7.359689
# current_episode 43, steps 80, losses are 11.292199
# current_episode 44, steps 0, losses are 0.663646
# current_episode 44, steps 10, losses are 11.244050
# current_episode 44, steps 20, losses are 13.217070
# current_episode 44, steps 30, losses are 8.948421
# current_episode 44, steps 40, losses are 10.700159
# current_episode 44, steps 50, losses are 14.487927
# current_episode 44, steps 60, losses are 14.432042
# current_episode 44, steps 70, losses are 7.650347
# current_episode 44, steps 80, losses are 15.453986
# current_episode 45, steps 0, losses are 0.749027
# current_episode 45, steps 10, losses are 12.830490
# current_episode 45, steps 20, losses are 15.829577
# current_episode 45, steps 30, losses are 10.964049
# current_episode 45, steps 40, losses are 16.905502
# current_episode 45, steps 50, losses are 21.239827
# current_episode 45, steps 60, losses are 12.173696
# current_episode 45, steps 70, losses are 8.674625
# current_episode 45, steps 80, losses are 23.937184
# current_episode 46, steps 0, losses are 0.987156
# current_episode 46, steps 10, losses are 14.747717
# current_episode 46, steps 20, losses are 19.346048
# current_episode 46, steps 30, losses are 12.057025
# current_episode 46, steps 40, losses are 22.633884
# current_episode 46, steps 50, losses are 30.048356
# current_episode 46, steps 60, losses are 12.537767
# current_episode 46, steps 70, losses are 9.634664
# current_episode 46, steps 80, losses are 32.089076
# current_episode 47, steps 0, losses are 1.342167
# current_episode 47, steps 10, losses are 23.302867
# current_episode 47, steps 20, losses are 23.549057
# current_episode 47, steps 30, losses are 16.647264
# current_episode 47, steps 40, losses are 43.366894
# current_episode 47, steps 50, losses are 44.671717
# current_episode 47, steps 60, losses are 15.234873
# current_episode 47, steps 70, losses are 10.889692
# current_episode 47, steps 80, losses are 30.965052
# current_episode 48, steps 0, losses are 1.112017
# current_episode 48, steps 10, losses are 20.695535
# current_episode 48, steps 20, losses are 23.423373
# current_episode 48, steps 30, losses are 12.687590
# current_episode 48, steps 40, losses are 36.102665
# current_episode 48, steps 50, losses are 31.576388
# current_episode 48, steps 60, losses are 11.384545
# current_episode 48, steps 70, losses are 7.742999
# current_episode 48, steps 80, losses are 22.672863
# current_episode 49, steps 0, losses are 0.958225
# current_episode 49, steps 10, losses are 17.763411
# current_episode 49, steps 20, losses are 17.952624
# current_episode 49, steps 30, losses are 10.128718
# current_episode 49, steps 40, losses are 32.986650
# current_episode 49, steps 50, losses are 30.229327
# current_episode 49, steps 60, losses are 11.533519
# current_episode 49, steps 70, losses are 7.154931
# current_episode 49, steps 80, losses are 20.198759
# current_episode 50, steps 0, losses are 1.029729
# current_episode 50, steps 10, losses are 16.697593
# current_episode 50, steps 20, losses are 15.174975
# current_episode 50, steps 30, losses are 8.366764
# current_episode 50, steps 40, losses are 23.336585
# current_episode 50, steps 50, losses are 23.098008
# current_episode 50, steps 60, losses are 10.896573
# current_episode 50, steps 70, losses are 6.747213
# current_episode 50, steps 80, losses are 14.611815

# %%
steps_test = int(len(df_test)/batch_size)
test_loss = 0.0
y_hat_arr = np.empty(shape = [0])
y_labels_arr = np.empty(shape = [0])

for t in range(steps_test-1):

    x_test,y_test,labels_test = get_batch(df_test,batch_size = batch_size, T = time_step, step = t, train = False)   
    y_hat = model.predict(x_test,y_test,sess) 
    y_hat_arr = np.concatenate([y_hat_arr,np.array(y_hat)])
    y_labels_arr = np.concatenate([y_labels_arr,np.array(labels_test)])
    test_loss += np.mean(np.square(y_hat - labels_test))

print "the mean squared error for test data are %f " % (test_loss*1.0/steps_test)
# Out:
# the mean squared error for test data are 1.749745

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

plot_num = 256

for i in range(steps_test-1):
    start_idx = i*plot_num
    end_idx = (i+1)*plot_num
    plt.figure()
    plt.plot(range(plot_num),y_hat_arr[start_idx:end_idx])
    plt.plot(range(plot_num),y_labels_arr[start_idx:end_idx])
    plt.draw()
    plt.savefig('./time_series/range_%i.png' % i)

# %%
print 'traninig data point %i' % len(df1)
print 'testing data point %i' % len(df_test)
print "the mean squared error for test data are %f " % (test_loss*1.0/steps_test)
# Out:
# traninig data point 22081
# testing data point 5518
# the mean squared error for test data are 1.749745
